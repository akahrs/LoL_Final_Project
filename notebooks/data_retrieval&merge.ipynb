# %% [markdown]
# ### Data Retrieval (loading data)

# %%
import pandas as pd

# %%
df_2014 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2014_LoL_esports_match_data_from_OraclesElixir_20220829.csv")
df_2015 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2015_LoL_esports_match_data_from_OraclesElixir_20220829.csv")
df_2016 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2016_LoL_esports_match_data_from_OraclesElixir_20220829.csv")
df_2017 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2017_LoL_esports_match_data_from_OraclesElixir_20220829.csv")
df_2018 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2018_LoL_esports_match_data_from_OraclesElixir_20220829.csv")

# %%
df_2019 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2019_LoL_esports_match_data_from_OraclesElixir_20220829.csv")
df_2020 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2020_LoL_esports_match_data_from_OraclesElixir_20220829.csv")
df_2021 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2021_LoL_esports_match_data_from_OraclesElixir_20220829.csv")
df_2022 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2022_LoL_esports_match_data_from_OraclesElixir_20220829.csv")
# Out:
# /tmp/ipykernel_11373/4043134581.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2022 = pd.read_csv("~/code/akahrs/LoL-Final-Project/raw_data/2022_LoL_esports_match_data_from_OraclesElixir_20220829.csv")

# %%
df = df_2014.append(df_2015).append(df_2016).append(df_2017).append(df_2018).append(df_2019).append(df_2020).append(df_2021).append(df_2022)
# Out:
# /tmp/ipykernel_11373/2638325461.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_2014.append(df_2015).append(df_2016).append(df_2017).append(df_2018).append(df_2019).append(df_2020).append(df_2021).append(df_2022)
# /tmp/ipykernel_11373/2638325461.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_2014.append(df_2015).append(df_2016).append(df_2017).append(df_2018).append(df_2019).append(df_2020).append(df_2021).append(df_2022)
# /tmp/ipykernel_11373/2638325461.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_2014.append(df_2015).append(df_2016).append(df_2017).append(df_2018).append(df_2019).append(df_2020).append(df_2021).append(df_2022)
# ...

# %%
df
# Out:
#                        gameid datacompleteness  \
# 0                    TRLH3/33         complete
# 1                    TRLH3/33         complete
# 2                    TRLH3/33         complete
# 3                    TRLH3/33         complete
# 4                    TRLH3/33         complete
# ...                       ...              ...
# 128899  ESPORTSTMNT02_2972906         complete
# 128900  ESPORTSTMNT02_2972906         complete
# 128901  ESPORTSTMNT02_2972906         complete
# 128902  ESPORTSTMNT02_2972906         complete
# 128903  ESPORTSTMNT02_2972906         complete
#
#                                                       url  league  year  \
# 0       http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2014
# 1       http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2014
# 2       http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2014
# 3       http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2014
# ...

# %%
df.to_csv("LoL_match_data_2014_to_2022_unprocessed.csv")
